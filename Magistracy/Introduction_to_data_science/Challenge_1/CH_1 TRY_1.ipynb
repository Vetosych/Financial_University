# %%
# импорт

import pandas as pd
import numpy as np

# %%
# загружаем файлы

file = pd.read_csv(r'C:\Users\Виталий\Desktop\Магистратура\1 модуль\Введение в науки о данных\Challenge_1/credit_train.csv')
file.head(1)
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid               445412  Short Term         709.0      1167493.0
#
#   Years in current job Home Ownership            Purpose  Monthly Debt  \
# 0              8 years  Home Mortgage  Home Improvements       5214.74
#
#    Years of Credit History  Months since last delinquent  \
# 0                     17.2                           NaN
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                        6                          1                  228190
#
#    Maximum Open Credit  Bankruptcies  Tax Liens
# 0             416746.0           1.0        0.0

# %%
# выделяем признаки

col_1 = pd.DataFrame(data = file 
                            .groupby('Loan Status')['Loan Status'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_2 = pd.DataFrame(data = file 
                            .groupby('Current Loan Amount')['Current Loan Amount'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_3 = pd.DataFrame(data = file 
                            .groupby('Term')['Term'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_4 = pd.DataFrame(data = file 
                            .groupby('Credit Score')['Credit Score'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_5 = pd.DataFrame(data = file 
                            .groupby('Annual Income')['Annual Income'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_6 = pd.DataFrame(data = file 
                            .groupby('Years in current job')['Years in current job'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_7 = pd.DataFrame(data = file 
                            .groupby('Home Ownership')['Home Ownership'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_8 = pd.DataFrame(data = file 
                            .groupby('Purpose')['Purpose'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_9 = pd.DataFrame(data = file 
                            .groupby('Monthly Debt')['Monthly Debt'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_10 = pd.DataFrame(data = file 
                            .groupby('Years of Credit History')['Years of Credit History'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_11 = pd.DataFrame(data = file 
                            .groupby('Months since last delinquent')['Months since last delinquent'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_12 = pd.DataFrame(data = file 
                            .groupby('Number of Open Accounts')['Number of Open Accounts'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_13 = pd.DataFrame(data = file 
                            .groupby('Number of Credit Problems')['Number of Credit Problems'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_14 = pd.DataFrame(data = file 
                            .groupby('Current Credit Balance')['Current Credit Balance'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_15 = pd.DataFrame(data = file 
                            .groupby('Maximum Open Credit')['Maximum Open Credit'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_16 = pd.DataFrame(data = file 
                            .groupby('Bankruptcies')['Bankruptcies'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )
col_17 = pd.DataFrame(data = file 
                            .groupby('Tax Liens')['Tax Liens'].count()
                            .reset_index(name='cnt')
                            .sort_values('cnt', ascending = False)
                    )

# %%
# проверка на null

#file['Loan Status']                     .isnull().sum() # 0
#file['Current Loan Amount']             .isnull().sum() # 0
#file['Term']                            .isnull().sum() # 0
#file['Credit Score']                    .isnull().sum() # 19154
#file['Annual Income']                   .isnull().sum() # 19154
#file['Years in current job']            .isnull().sum() # 4222
#file['Home Ownership']                  .isnull().sum() # 0
#file['Purpose']                         .isnull().sum() # 0
#file['Monthly Debt']                    .isnull().sum() # 0
#file['Years of Credit History']         .isnull().sum() # 0
#file['Months since last delinquent']    .isnull().sum() # 53141
#file['Number of Open Accounts']         .isnull().sum() # 0
#file['Number of Credit Problems']       .isnull().sum() # 0
#file['Current Credit Balance']          .isnull().sum() # 0
#file['Maximum Open Credit']             .isnull().sum() # 2
#file['Bankruptcies']                    .isnull().sum() # 204
#file['Tax Liens']                       .isnull().sum() # 10
# Out:
# 10
